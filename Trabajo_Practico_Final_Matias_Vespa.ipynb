# %% [markdown]
# <a href="https://colab.research.google.com/github/Ranger9707/Python-ciencia-datos/blob/main/Trabajo_Practico_Final_Matias_Vespa.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #TP FINAL

# %% [markdown]
# **Ejercicio 1**\
# Buscar un dataset (Que no sea los trabajados en clases)
#
# **Ejercicio 2**\
# Realizar una introduccion al dataset de que se trata,definir sus variables (Diccionario de datos)
#
# **Ejercicio 3**\
# Identificar el tipo de variable,decide justificando su respuesta.
#
# **Ejercicio 4**\
# Detectar Valores Ausente  y Valores Atipicos .Decidir si eliminarlos y el por que de la eleccion.
#
# **Ejercicio 5**\
# Realizar un analisis univariado y en base a esos graficos,sacar conclusiones.
#
# **Ejercicio 6**\
# Realizar analisis de matriz corelacion y explicar que variable estan correlacionadas

# %% [markdown]
# # Desarrollo dataset "Video Game Sales with Ratings"
#
# El dataset elegido contiene informacion sobre ventas de videojuegos desde los años 1985 hasta 2016 aproximadamente, con sus nombres, desarrolladores, numero de ventas por region.

# %% [markdown]
# # **Descripcion del dataset**

# %%
#Importo bibliotecas
import warnings
warnings.filterwarnings("ignore")
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.patches as mpatches

# %%
data=pd.read_csv('/content/Video_Games_Sales.csv')
df=pd.DataFrame(data)

# %%
print('El dataset tiene ' + str(df.shape[0]) + ' filas y ' + str(df.shape[1]) + ' columnas')
# Out:
# El dataset tiene 16719 filas y 16 columnas

# %%
df.head(10)
# Out:
#                         Name Platform  Year_of_Release         Genre  \
# 0                 Wii Sports      Wii           2006.0        Sports
# 1          Super Mario Bros.      NES           1985.0      Platform
# 2             Mario Kart Wii      Wii           2008.0        Racing
# 3          Wii Sports Resort      Wii           2009.0        Sports
# 4   Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing
# 5                     Tetris       GB           1989.0        Puzzle
# 6      New Super Mario Bros.       DS           2006.0      Platform
# 7                   Wii Play      Wii           2006.0          Misc
# 8  New Super Mario Bros. Wii      Wii           2009.0      Platform
# 9                  Duck Hunt      NES           1984.0       Shooter
#
#   Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  \
# 0  Nintendo     41.36     28.96      3.77         8.45         82.53
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16719 entries, 0 to 16718
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             16717 non-null  object
#  1   Platform         16719 non-null  object
#  2   Year_of_Release  16450 non-null  float64
#  3   Genre            16717 non-null  object
#  4   Publisher        16665 non-null  object
#  5   NA_Sales         16719 non-null  float64
#  6   EU_Sales         16719 non-null  float64
#  7   JP_Sales         16719 non-null  float64
#  8   Other_Sales      16719 non-null  float64
#  9   Global_Sales     16719 non-null  float64
#  10  Critic_Score     8137 non-null   float64
#  11  Critic_Count     8137 non-null   float64
#  12  User_Score       10015 non-null  object
#  13  User_Count       7590 non-null   float64
#  14  Developer        10096 non-null  object
#  15  Rating           9950 non-null   object
# dtypes: float64(9), object(7)
# ...

# %%
df.describe()
# Out:
#        Year_of_Release      NA_Sales      EU_Sales      JP_Sales  \
# count     16450.000000  16719.000000  16719.000000  16719.000000
# mean       2006.487356      0.263330      0.145025      0.077602
# std           5.878995      0.813514      0.503283      0.308818
# min        1980.000000      0.000000      0.000000      0.000000
# 25%        2003.000000      0.000000      0.000000      0.000000
# 50%        2007.000000      0.080000      0.020000      0.000000
# 75%        2010.000000      0.240000      0.110000      0.040000
# max        2020.000000     41.360000     28.960000     10.220000
#
#         Other_Sales  Global_Sales  Critic_Score  Critic_Count    User_Count
# count  16719.000000  16719.000000   8137.000000   8137.000000   7590.000000
# mean       0.047332      0.533543     68.967679     26.360821    162.229908
# std        0.186710      1.547935     13.938165     18.980495    561.282326
# min        0.000000      0.010000     13.000000      3.000000      4.000000
# ...

# %%
data.isnull()
# Out:
#         Name  Platform  Year_of_Release  Genre  Publisher  NA_Sales  EU_Sales  \
# 0      False     False            False  False      False     False     False
# 1      False     False            False  False      False     False     False
# 2      False     False            False  False      False     False     False
# 3      False     False            False  False      False     False     False
# 4      False     False            False  False      False     False     False
# ...      ...       ...              ...    ...        ...       ...       ...
# 16714  False     False            False  False      False     False     False
# 16715  False     False            False  False      False     False     False
# 16716  False     False            False  False      False     False     False
# 16717  False     False            False  False      False     False     False
# 16718  False     False            False  False      False     False     False
#
# ...

# %%
df.isnull().sum()
# Out:
# Name                  2
# Platform              0
# Year_of_Release     269
# Genre                 2
# Publisher            54
# NA_Sales              0
# EU_Sales              0
# JP_Sales              0
# Other_Sales           0
# Global_Sales          0
# Critic_Score       8582
# Critic_Count       8582
# User_Score         6704
# User_Count         9129
# Developer          6623
# Rating             6769
# dtype: int64

# %%
df.boxplot(figsize=(13, 4))
plt.grid(False)
plt.show()

# %% [markdown]
#  **Valores atipicos y ausentes:
# Decidi no eliminar valores ausentes ya que aun son datos de informacion utiles, que pueden ser calculados y usados para sacar conclusiones, la falta de los datos en este case no daña al analisis**

# %% [markdown]
# Analisis de las variables:
#
# * Name: Variable categórica - Nombre del juego.
#
# * Platform: Variable categórica - Plataforma en la que se lanzó el juego
# .
# * Year_of_Release: Variable numérica discreta - Año de lanzamiento del juego.
#
# * Genre: Variable categórica  - Género del juego.
#
# * Publisher: Variable categórica  - Editorial o compañía que publicó el juego.
#
# * NA_Sales: Variable numérica continua - Ventas en América del Norte.
#
# * EU_Sales: Variable numérica continua - Ventas en Europa.
#
# * JP_Sales: Variable numérica continua - Ventas en Japón.
#
# * Other_Sales: Variable numérica continua - Ventas en otras regiones.
#
# * Global_Sales: Variable numérica continua - Ventas globales totales.
#
# * Critic_Score: Variable numérica discreta - Puntuación del crítico.
#
# * Critic_Count: Variable numérica discreta - Cantidad de críticas o revisiones de críticos.
#
# * User_Score: Variable numérica discreta o categórica  - Puntuación de los usuarios.
#
# * User_Count: Variable numérica discreta - Cantidad de calificaciones de usuarios.
#
# * Developer: Variable categórica  - Desarrollador del juego.
#
# * Rating: Variable categórica - Clasificación de contenido del juego
#
#
#
#
#
# **Name**: Se eligió como una variable categórica ya que representa el nombre único de cada juego, y los juegos generalmente se distinguen por su título.
#
# **Platform:** Fue seleccionada como una variable categórica  porque indica la plataforma en la que se lanzó el juego, y las plataformas son categorías específicas y discretas.
#
# **Year_of_Release:** Se consideró una variable numérica discreta porque representa el año en que se lanzó el juego, y los años son valores discretos y ordenados.
#
# **Genre:** Se clasificó como una variable categórica ya que describe la categoría o género al que pertenece el juego, y estos géneros son categorías específicas.
#
# **Publisher:** Fue tratada como una variable categórica porque representa la empresa editorial responsable del juego, y cada empresa es una entidad única.
#
# **NA_Sales, EU_Sales, JP_Sales, Other_Sales, Global_Sales:** Se consideraron variables numéricas continuas porque representan cifras de ventas que pueden tomar cualquier valor en un rango continuo.
#
# **Critic_Score, Critic_Count, User_Score, User_Count:** Se clasificaron como variables numéricas discretas ya que representan puntuaciones y recuentos, que son valores enteros y específicos.
#
# **Developer:** Fue seleccionada como una variable categórica ya que identifica la entidad o empresa que desarrolló el juego, y cada desarrollador es único.
#
# **Rating:** Se eligió como una variable categórica ya que representa la clasificación de contenido del juego, que cae en categorías específicas.

# %% [markdown]
# # Analisis Univariado

# %% [markdown]
# # Produccion de videojuegos por año de salida

# %%
sns.displot(df.Year_of_Release.dropna(), bins = 40, color="Green");
plt.title('Produccion de videojuegos por año de salida')
plt.grid(False)
plt.show()

# %% [markdown]
# **Una forma que no siempre sube, demostro un incremento masivo desde los años 2000 llegando a su maximo entre los 2009-2010, en algun momento la produccion disminuyo entre los años 2010 a 2016, durante ese período, la industria de los videojuegos experimentó un crecimiento significativo. La cantidad de lanzamientos de juegos por año aumentó drásticamente, y la diversidad de géneros también se amplió, reflejando un mercado en constante evolución.**

# %% [markdown]
# # Puntuaciones de los videojuegos

# %% [markdown]
# **Puntuacion de los criticos**

# %%
sns.distplot(df.Critic_Score.dropna(), color="red")
plt.title('Puntuacion de los criticos')
plt.grid(True)
plt.ylabel('Densidad')
plt.xlabel('Puntuacion')
plt.show()

# %% [markdown]
# **Cantidad de criticas hechas por criticos especializados**

# %%
sns.distplot(df.Critic_Count.dropna(), color="red");
plt.title('Cantidad de criticas hechas por criticos especializados')
plt.grid(True)
plt.ylabel('Densidad')
plt.xlabel('Cantidad de Críticas')
plt.show()

# %% [markdown]
# **Puntuacion de los usuarios**

# %%
df['User_Score'] = pd.to_numeric(df['User_Score'], errors='coerce')
sns.distplot(df.User_Score.dropna(), color="red");
plt.title('Puntuacion de los usuarios')
plt.grid(True)
plt.ylabel('Densidad')
plt.xlabel('Puntuacion')
plt.show()

# %% [markdown]
# **Cantidad de criticas hechas por usuarios**

# %%
sns.distplot(df.User_Count.dropna(), color="red");
plt.title('Cantidad de criticas hechas por usuarios')
plt.grid(True)
plt.ylabel('Densidad')
plt.xlabel('Cantidad de Críticas')
plt.show()

# %% [markdown]
# **En términos generales, se observa que las calificaciones de los críticos tienden a ser más cautelosas en comparación con las calificaciones de los usuarios. Las calificaciones de los usuarios muestran una tendencia más marcada hacia valores más bajos, y su punto más frecuente se encuentra en un intervalo de puntuaciones más elevadas.**

# %% [markdown]
# # Ventas

# %% [markdown]
# **Ventas globales**

# %%
sns.histplot(df.Global_Sales.dropna()[df.Global_Sales > 1], kde=False)
plt.title('Ventas Globales')
plt.grid(True)
plt.ylabel('Cantidad')
plt.xlabel('Ventas Globales')
plt.show()

# %%
sns.boxplot(df.Global_Sales, showfliers=False)
plt.grid(True)
plt.show()

# %%
sns.boxplot(df.Global_Sales)
plt.grid(True)
plt.show()

# %% [markdown]
# **Ventas norteamerica**

# %%
sns.histplot(df.NA_Sales.dropna()[df.NA_Sales > 1], kde=False)
plt.title('Ventas Norteamerica')
plt.grid(True)
plt.ylabel('Cantidad')
plt.xlabel('Ventas en Norteamerica')
plt.show()

# %%
sns.boxplot(df.NA_Sales, showfliers=False)
plt.grid(True)
plt.show()

# %%
sns.boxplot(df.NA_Sales)
plt.grid(True)
plt.show()

# %% [markdown]
# **Ventas Europa**

# %%
sns.histplot(df.EU_Sales.dropna()[df.EU_Sales > 1], kde=False)
plt.title('Ventas Europa')
plt.grid(True)
plt.ylabel('Cantidad')
plt.xlabel('Ventas en Europa')
plt.show()

# %%
sns.boxplot(df.EU_Sales, showfliers=False)
plt.grid(True)
plt.show()

# %%
sns.boxplot(df.EU_Sales)
plt.grid(True)
plt.show()

# %% [markdown]
# **Ventas Japon**

# %%
sns.histplot(df.JP_Sales.dropna()[df.JP_Sales > 1], kde=False)
plt.title('Ventas Japon')
plt.grid(True)
plt.ylabel('Cantidad')
plt.xlabel('Ventas en Japon')
plt.show()

# %%
sns.boxplot(df.JP_Sales, showfliers=False)
plt.grid(True)
plt.show()

# %%
sns.boxplot(df.JP_Sales)
plt.grid(True)
plt.show()

# %% [markdown]
# **ventas resto del mundo**

# %%
sns.histplot(df.Other_Sales.dropna()[df.Other_Sales > 1], kde=False)
plt.title('Ventas Resto del mundo')
plt.grid(True)
plt.ylabel('Cantidad')
plt.xlabel('Ventas en el resto del mundo')
plt.show()

# %%
sns.boxplot(df.Other_Sales, showfliers=False)
plt.grid(True)
plt.show()

# %%
sns.boxplot(df.Other_Sales)
plt.grid(True)
plt.show()

# %% [markdown]
# **El patrón común en estos datos muestra una disminución exponencial. Algunas puntuaciones/ventas son excepcionales, pero luego disminuyen rápidamente. En cuanto a las ventas, las más altas son las de América del Norte, con una gran diferencia, seguidas por la Unión Europea y luego Japón, quedando al final las ventas combinadas en otros países.**

# %% [markdown]
# # Plataformas

# %%
plt.figure(figsize=(13, 4))
sns.countplot(data=df, x='Platform', order=df['Platform'].value_counts().index)
plt.xticks(rotation=90)
plt.title('Cantidad de juegos por plataforma')
plt.xlabel('Plataforma')
plt.ylabel('Cantidad de Juegos')
plt.show()

# %%
plt.figure(figsize=(13, 4))
sns.countplot(data=df, x='Genre', order=df['Genre'].value_counts().index)
plt.xticks(rotation=90)
plt.title('Cantidad de juegos por genero')
plt.xlabel('Genero')
plt.ylabel('Cantidad de Juegos')
plt.show()

# %%
plt.figure(figsize=(13, 4))
sns.countplot(data=df, x='Developer', order=df['Developer'].value_counts().iloc[:40].index.tolist())
plt.xticks(rotation=90)
plt.title('Cantidad de juegos por desarrollador')
plt.xlabel('Desarrollador')
plt.ylabel('Cantidad de Juegos')
plt.show()

# %% [markdown]
# Los géneros populares como los juegos de acción, aventuras y deportes continuaron teniendo una presencia constante en los lanzamientos. Se puede llegar a la conclusion que estos géneros a menudo atraen a un público amplio y generaan ventas significativas.
#
# A medida que avanzaban los años, las plataformas de juego también evolucionaban. Vimos la transición desde las consolas más antiguas hasta las plataformas más modernas, como la PlayStation original, la PlayStation 2, la Xbox y la Xbox 360. Aun asi se puede ver la dominacion de dos consolas especificas, la playstation 2 y la Nintendo DS, que se puede relacionar con su fecha de lanzamiento y el boom de produccion de videojuegos
#
# En los desarrolladores se puede ver claramente una dominacion de varios desarrolladores especificos que son los que mas producen, abarcando el mercado

# %% [markdown]
# # Crossplots

# %%
pairplot = sns.pairplot(df, diag_kind='kde', height=2.5)
pairplot.fig.subplots_adjust(top=0.95)
pairplot.fig.suptitle('Relaciones entre Variables en el DataFrame', fontsize=16)

for i, j in zip(*plt.np.triu_indices_from(pairplot.axes, 1)):
    pairplot.axes[i, j].set_visible(False)

plt.show()

# %% [markdown]
# # Matriz Correlacion

# %%
plt.figure(figsize=(12, 8))

corr = df.corr()
sns.heatmap(corr,
            xticklabels = corr.columns.values,
            yticklabels = corr.columns.values,
            annot = True);

# %% [markdown]
# # Ventas vs. numero de lanzamientos

# %%
agrupado_df = df.groupby('Year_of_Release').agg({'Name': 'count', 'Global_Sales': 'sum'}).reset_index()
normalized_df = (agrupado_df - agrupado_df.mean()) / agrupado_df.std()
normalized_df['year'] = agrupado_df['Year_of_Release']

plt.figure(figsize=(10, 5))
sns.pointplot(x=normalized_df.year, y=normalized_df.Name, color='blue', label='Release Count')
sns.pointplot(x=normalized_df.year, y=normalized_df.Global_Sales, color='red', label='Global Sales')

plt.legend(handles=[mpatches.Patch(color='blue', label='Numero de lanzamientos'),
                    mpatches.Patch(color='red', label='Ventas Globales')],
           loc='upper left', fontsize=16)
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Las formas siguen una buena correspondencia entre sí, no se observa ninguna discrepancia extraña, como altas ventas con pocas publicaciones o viceversa. Otro aspecto a considerar es que el número de lanzamientos tiene una tendencia más uniforme en comparación con las ventas, que parecen ser más difíciles de predecir con precisión. En resumen, las tendencias entre la cantidad de lanzamientos y las ventas globales están bien alineadas, aunque las ventas muestran más variabilidad en comparación con la fluidez del número de lanzamientos.

# %% [markdown]
# # Evolución de las Ventas por Género

# %%
genre_sales = df.groupby(['Year_of_Release', 'Genre']).Global_Sales.sum()
genre_sales_percentages = (genre_sales * 100) / df.groupby(['Year_of_Release']).Global_Sales.sum()

plt.figure(figsize=(15, 5))
genre_sales_percentages.unstack().plot(kind='area', stacked=True, colormap='Spectral', grid=False)
plt.title('Porcentaje de Ventas por Género por Año')
plt.xlabel('Año de Lanzamiento')
plt.ylabel('Porcentaje de Ventas')
plt.legend(title='Genre', bbox_to_anchor=(1.05, 1), loc='upper left')

plt.show()

yearly_sales = df.groupby(['Year_of_Release', 'Genre']).Global_Sales.sum()

plt.figure(figsize=(15, 5))
yearly_sales.unstack().plot(kind='area', stacked=True, colormap='Spectral')
plt.title('Ventas Anuales por Género')
plt.xlabel('Año de Lanzamiento')
plt.ylabel('Año de Lanzamiento')
plt.legend(title='Genre', bbox_to_anchor=(1.05, 1), loc='upper left')

plt.show()

# %% [markdown]
# El género "acción" es claramente el favorito entre los jugadores. Lo interesante es que cuando las ventas de juegos comenzaron a bajar alrededor de 2009, las ventas de juegos de "acción" se quedaron prácticamente igual.
#
# Esto sugiere que, aunque en general las ventas de juegos estaban bajando, la gente seguía interesada en los juegos de acción. Parece que a los fans de este género les seguía gustando y apoyando los juegos de acción, incluso cuando otras cosas en el mundo de los videojuegos estaban cambiando.

# %% [markdown]
# # Ventas totales por genero

# %%
genre_sales = df.groupby('Genre').Global_Sales.sum()

ax = genre_sales.sort_values(ascending=False).plot(kind='bar', figsize=(13, 5))

total_sum = genre_sales.sum()
for p in ax.patches:
    height = p.get_height()
    ax.annotate(f"{round(height)}\n{round(height / total_sum * 100)}%",
                (p.get_x() * 1.007, height * 0.75),
                color='black')

plt.xlabel('Genero')
plt.ylabel('Ventas Totales')
plt.title('Ventas Totales por genero')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# Los resultados numéricos coinciden con los análisis que hemos realizado hasta el momento. Es evidente que el género de "acción" lidera en términos de ventas totales. Este género parece tener una conexión particularmente sólida con los jugadores, ya que ha logrado acumular la mayor cantidad de ventas en comparación con otros géneros.

# %% [markdown]
# # Evolución de las Ventas por Clasificación

# %%
rating_sales_percentages = (df.groupby(['Year_of_Release', 'Rating']).Global_Sales.sum() * 100) / df.groupby(['Year_of_Release']).Global_Sales.sum()

plt.figure(figsize=(13, 4))
rating_sales_percentages.unstack().plot(kind='area', stacked=True, colormap='Spectral', figsize=(13, 4))
plt.title('Porcentaje de Ventas por Clasificación por Año')
plt.xlabel('Año de lanzamiento')
plt.ylabel('Porcentaje de ventas')
plt.legend(title='Rating', bbox_to_anchor=(1.05, 1), loc='upper left')

plt.show()

# %% [markdown]
# Mirando este gráfico, es fácil notar que la mayoría de los juegos lanzados tienen una clasificación "E" (para todos). Esto significa que muchos de estos juegos están diseñados para ser jugados por cualquier persona, sin importar su edad.
#
# Esta alta cantidad de juegos "E" sugiere que la industria de los videojuegos quiere que mucha gente pueda disfrutar de sus productos. Quieren hacer juegos que sean aptos para todos, desde niños hasta adultos. También podría ser una manera de asegurarse de que los padres se sientan cómodos dejando que sus hijos jueguen estos juegos sin preocuparse por el contenido.

# %% [markdown]
# # Puntuaciones de criticos vs puntuaciones de usuarios

# %%
df['Critic_Score'] = pd.to_numeric(df['Critic_Score'], errors='coerce')
df['User_Score'] = pd.to_numeric(df['User_Score'], errors='coerce')

g = sns.jointplot(x='Critic_Score', y='User_Score', data=df, kind='hex',cmap="hot", height=6)
sns.regplot(x='Critic_Score', y='User_Score', data=df, scatter=False, ax=g.ax_joint,line_kws={"color": "grey"} )
g.set_axis_labels("Critic Score", "User Score")
g.ax_joint.tick_params(labelsize=10)
g.ax_joint.set_title(g.ax_joint.get_title(), fontsize=12)

plt.show()

# %% [markdown]
# Se nota en el primer gráfico que los usuarios suelen dar puntuaciones más altas en comparación con las puntuaciones de los críticos. El gráfico muestra claramente que las puntuaciones de los críticos tienen una relación más fuerte con las ventas. En cambio, las puntuaciones de los usuarios apenas tienen relación con las ventas, ya que van subiendo y bajando alrededor del número cero.

# %% [markdown]
# # Ventas regionales de generos

# %%
genero_geo_rankings = [
    df.groupby('Genre').sum().unstack().NA_Sales.sort_values(ascending=False).index,
    df.groupby('Genre').sum().unstack().EU_Sales.sort_values(ascending=False).index,
    df.groupby('Genre').sum().unstack().Other_Sales.sort_values(ascending=False).index,
    df.groupby('Genre').sum().unstack().JP_Sales.sort_values(ascending=False).index
]

genre_geo_rank_df = pd.DataFrame(columns=['genre', 'rank_type', 'rank'])

for region, rankings in enumerate(genre_geo_rankings):
    for rank, genre in enumerate(rankings):
        genre_geo_rank_df = genre_geo_rank_df.append({'genre': genre, 'rank_type': region, 'rank': rank}, ignore_index=True)


plt.figure(figsize=(10, 8))
sns.barplot(x='rank_type', y=12 - genre_geo_rank_df['rank'], hue='genre', data=genre_geo_rank_df)

plt.xlabel('Region')
plt.ylabel('Clasificación de Género')
plt.title('Clasificación de Género por Region')

x_labels = ['NorteAmerica', 'Europa', 'Resto del mundo', 'Japan']
plt.xticks(range(4), x_labels)
plt.gca().invert_yaxis()


plt.legend(title='Genre', bbox_to_anchor=(1.05, 1), loc='upper left')

plt.tight_layout()
plt.show()

# %% [markdown]
# Se nota que los gustos de los jugadores en Japón son muy diferentes de los de las otras tres regiones. En cuanto a las otras tres, son más o menos similares; tal vez solo los géneros de plataformas y carreras cambian su posición en más de una región.

# %% [markdown]
# # Gráfico de dispersión entre Ventas Globales y Ventas Regionales

# %%
ventas_globales = ['NA_Sales', 'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales']
ventas_normalizadas = (df[ventas_globales] - df[ventas_globales].mean()) / (df[ventas_globales].max() - df[ventas_globales].min())

markers = ['+', '.', 'x', 'o']
regiones = ['Norteamérica', 'Unión Europea', 'Japón', 'Otras Regiones']

plt.figure(figsize=(10, 6))
for col, marker, region in zip(ventas_normalizadas.columns[:-1], markers, regiones):
    sns.regplot(x=ventas_normalizadas.Global_Sales, y=ventas_normalizadas[col], marker=marker, label=region)

plt.xlabel('Ventas Globales Normalizadas')
plt.ylabel('Ventas Regionales Normalizadas')
plt.title('Relación entre Ventas Globales y Ventas Regionales')
plt.xlim(-0.1, 1.1)
plt.ylim(-0.1, 1.1)
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Plataforma más vendida cada año

# %%
temp = df.groupby(['Year_of_Release', 'Platform']).sum().reset_index().groupby('Year_of_Release')

plataforma_anual_ganadora_df = pd.DataFrame()

for año, grupo in temp:
    año_actual = temp.get_group(año)
    ventas_maximas_este_año = 0.0
    ganadora_actual = ""
    fila = {'año': "", 'ganadora': "", 'ventas': ""}
    for índice, datos_plataforma in año_actual.iterrows():
        if datos_plataforma.Global_Sales > ventas_maximas_este_año:
            ventas_maximas_este_año = datos_plataforma.Global_Sales
            ganadora_actual = datos_plataforma.Platform

    fila['año'] = año
    fila['ganadora'] = ganadora_actual
    fila['ventas'] = ventas_maximas_este_año
    plataforma_anual_ganadora_df = plataforma_anual_ganadora_df.append(fila, ignore_index=True)

plt.figure(figsize=(13, 4))

grafico = sns.pointplot(x=plataforma_anual_ganadora_df.año,
                        y=plataforma_anual_ganadora_df.ventas,
                        hue=plataforma_anual_ganadora_df.ganadora,
                        markers=["o", "s", "D", "P", "^", "v", "<", ">", "h", "*", "x"])

grafico.set_xticklabels(grafico.get_xticklabels(), rotation=90)

plt.xlabel('Año')
plt.ylabel('Ventas Globales')
plt.title('Plataforma Ganadora de Ventas Cada Año')
plt.legend(title='Plataforma', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %% [markdown]
# # Principales Editoras

# %% [markdown]
# **Por ventas**

# %%
publisher_sales = df.groupby(['Publisher'])['Global_Sales'].sum()
top_publishers = publisher_sales.sort_values(ascending=False).head(10)

fig, ax = plt.subplots(figsize=(10, 6))
top_publishers.plot(kind='barh', color='skyblue', ax=ax)

ax.set_xlabel('Ventas Globales (en millones)')
ax.set_ylabel('Editor')
ax.set_title('Top 10 Editores por Ventas Globales')
ax.invert_yaxis()

plt.tight_layout()
plt.show()

# %% [markdown]
# **Por numero de juegos lanzados**

# %%
publisher_game_counts = df.groupby(['Publisher'])['Name'].count()
top_publishers = publisher_game_counts.sort_values(ascending=False).head(10)
fig, ax = plt.subplots(figsize=(10, 6))
top_publishers.plot(kind='barh', color='lightgreen', ax=ax)

ax.set_xlabel('Número de Juegos Publicados')
ax.set_ylabel('Editor')
ax.set_title('Top 10 Editores por Número de Juegos Publicados')
ax.invert_yaxis()

plt.tight_layout()
plt.show()

# %% [markdown]
# **Ventas Globales Promedio**

# %%
filtered_publishers = df.groupby(['Publisher']).filter(lambda x: len(x) > 5)
publisher_yearly_sales = filtered_publishers.groupby(['Publisher', 'Year_of_Release'], as_index=False)['Global_Sales'].mean()
avg_publisher_sales = publisher_yearly_sales.groupby('Publisher')['Global_Sales'].mean().sort_values(ascending=False).head(10)


fig, ax = plt.subplots(figsize=(10, 6))
avg_publisher_sales.plot(kind='barh', color='lightcoral', ax=ax)

ax.set_xlabel('Ventas Globales Promedio')
ax.set_ylabel('Editor')
ax.set_title('Top 10 Editores por Ventas Globales Promedio')
ax.invert_yaxis()

plt.tight_layout()
plt.show()

# %%
top_publishers = ['Electronic Arts', 'Activision', 'Namco Bandai Games', 'Ubisoft', 'Konami Digital Entertainment',
                  'THQ', 'Nintendo', 'Sony Computer Entertainment', 'Sega', 'Take-Two Interactive',
                  'Sony Computer Entertainment Europe', 'Microsoft Game Studios', 'Enix Corporation', 'Bethesda Softworks', 'SquareSoft',
                  'Take-Two Interactive', 'LucasArts', '989 Studios', 'Hasbro Interactive', 'Universal Interactive']

top_publisher_df = df[df['Publisher'].isin(top_publishers)]
fig, ax = plt.subplots(figsize=(10, 8))
top_publisher_df.groupby('Publisher')['Global_Sales'].mean().sort_values(ascending=True).plot(kind='barh', color='orange', ax=ax)
ax.set_xlabel('Ventas Globales Promedio')
ax.set_ylabel('Editor')
ax.set_title('Ventas Globales Promedio de los Principales Editores')

plt.tight_layout()
plt.show()

# %% [markdown]
# **Principales editoras por region**

# %%
publisher_sales = df.groupby('Publisher')['NA_Sales'].sum().sort_values(ascending=False).head(10)
fig, ax = plt.subplots(figsize=(13, 5))
publisher_sales.plot(kind='bar', ax=ax, color='dodgerblue')

ax.set_xlabel('Editor')
ax.set_ylabel('Ventas en América del Norte')
ax.set_title('Top 10 Editores por Ventas en América del Norte')

for p in ax.patches:
    height = p.get_height()
    ax.annotate(f'{height:.0f}\n{height / df.NA_Sales.sum() * 100:.1f}%',
                (p.get_x() + p.get_width() / 2, height - 85),
                ha='center', color='white', fontsize=12, fontweight='bold')
plt.show()

# %%
publisher_sales = df.groupby('Publisher')['EU_Sales'].sum().sort_values(ascending=False).head(10)
fig, ax = plt.subplots(figsize=(13, 5))
publisher_sales.plot(kind='bar', ax=ax, color='dodgerblue')

ax.set_xlabel('Editor')
ax.set_ylabel('Ventas en Europa')
ax.set_title('Top 10 Editores por Ventas en Europa')

for p in ax.patches:
    height = p.get_height()
    ax.annotate(f'{height:.0f}\n{height / df.EU_Sales.sum() * 100:.1f}%',
                (p.get_x() + p.get_width() / 2, height - 85),
                ha='center', color='white', fontsize=12, fontweight='bold')
plt.show()

# %%
publisher_sales = df.groupby('Publisher')['JP_Sales'].sum().sort_values(ascending=False).head(10)
fig, ax = plt.subplots(figsize=(13, 5))
publisher_sales.plot(kind='bar', ax=ax, color='dodgerblue')

ax.set_xlabel('Editor')
ax.set_ylabel('Ventas en Japon')
ax.set_title('Top 10 Editores por Ventas en Japon')

for p in ax.patches:
    height = p.get_height()
    ax.annotate(f'{height:.0f}\n{height / df.JP_Sales.sum() * 100:.1f}%',
                (p.get_x() + p.get_width() / 2, height - 85),
                ha='center', color='white', fontsize=12, fontweight='bold')
plt.show()

# %%
publisher_sales = df.groupby('Publisher')['Other_Sales'].sum().sort_values(ascending=False).head(10)
fig, ax = plt.subplots(figsize=(13, 5))
publisher_sales.plot(kind='bar', ax=ax, color='dodgerblue')

ax.set_xlabel('Editor')
ax.set_ylabel('Ventas en el resto del mundo')
ax.set_title('Top 10 Editores por Ventas en el resto del mundo')

for p in ax.patches:
    height = p.get_height()
    ax.annotate(f'{height:.0f}\n{height / df.Other_Sales.sum() * 100:.1f}%',
                (p.get_x() + p.get_width() / 2, height - 85),
                ha='center', color='white', fontsize=12, fontweight='bold')
plt.show()

# %% [markdown]
# La tendencia se repite en América del Norte, la Unión Europea y otras partes del mundo. Sin embargo, Japón continúa destacándose como una región con características únicas.

# %% [markdown]
# # Genero por region

# %%
genre_sales = df.groupby('Genre')['NA_Sales'].sum().sort_values(ascending=False)

fig, ax = plt.subplots(figsize=(10, 6))
genre_sales.plot(kind='bar', color='salmon', ax=ax)

ax.set_xlabel('Género')
ax.set_ylabel('Ventas en América del Norte')
ax.set_title('Ventas por Género en América del Norte')
plt.xticks(rotation=45, ha='right')
for p in ax.patches:
    ax.annotate(f'{p.get_height():.0f}',
                (p.get_x() + p.get_width() / 2, p.get_height()),
                ha='center', va='bottom', color='black', fontsize=10, fontweight='bold')
plt.tight_layout()
plt.show()

# %%
genre_sales = df.groupby('Genre')['EU_Sales'].sum().sort_values(ascending=False)

fig, ax = plt.subplots(figsize=(10, 6))
genre_sales.plot(kind='bar', color='yellow', ax=ax)

ax.set_xlabel('Género')
ax.set_ylabel('Ventas en Europa')
ax.set_title('Ventas por Género en Europa')
plt.xticks(rotation=45, ha='right')
for p in ax.patches:
    ax.annotate(f'{p.get_height():.0f}',
                (p.get_x() + p.get_width() / 2, p.get_height()),
                ha='center', va='bottom', color='black', fontsize=10, fontweight='bold')
plt.tight_layout()
plt.show()

# %%
genre_sales = df.groupby('Genre')['JP_Sales'].sum().sort_values(ascending=False)

fig, ax = plt.subplots(figsize=(10, 6))
genre_sales.plot(kind='bar', color='Pink', ax=ax)

ax.set_xlabel('Género')
ax.set_ylabel('Ventas en Japon')
ax.set_title('Ventas por Género en Japon')
plt.xticks(rotation=45, ha='right')
for p in ax.patches:
    ax.annotate(f'{p.get_height():.0f}',
                (p.get_x() + p.get_width() / 2, p.get_height()),
                ha='center', va='bottom', color='black', fontsize=10, fontweight='bold')
plt.tight_layout()
plt.show()

# %%
genre_sales = df.groupby('Genre')['Other_Sales'].sum().sort_values(ascending=False)

fig, ax = plt.subplots(figsize=(10, 6))
genre_sales.plot(kind='bar', color='Green', ax=ax)

ax.set_xlabel('Género')
ax.set_ylabel('Ventas por genero en el resto del mundo')
ax.set_title('Ventas por género en el resto del mundo')
plt.xticks(rotation=45, ha='right')
for p in ax.patches:
    ax.annotate(f'{p.get_height():.0f}',
                (p.get_x() + p.get_width() / 2, p.get_height()),
                ha='center', va='bottom', color='black', fontsize=10, fontweight='bold')
plt.tight_layout()
plt.show()

# %% [markdown]
# Sabíamos que el gusto japonés por los videojuegos era diferente, pero al analizar las ventas, encontramos algo aún más interesante: su preferencia está claramente inclinada hacia los juegos de ro

# %% [markdown]
# # Juegos con mas recaudacion

# %%
top_games = df.sort_values('Global_Sales', ascending=False).head(10)

fig, ax = plt.subplots(figsize=(10, 6))
ax.barh(top_games['Name'], top_games['Global_Sales'], color='Blue')
ax.set_xlabel('Ventas Globales (en millones)')
ax.set_ylabel('Juego')
ax.set_title('Top 10 Juegos con Mayores Ventas Globales')
ax.invert_yaxis()

plt.tight_layout()
plt.show()

# %% [markdown]
# # Juegos Más Rentables en cada Género

# %%
x = df.groupby(['Genre', 'Name']).sum().reset_index().groupby('Genre')
best_selling_titles_by_genre_df = pd.DataFrame()
for name, group in x:
    temp_col = group.sort_values('Global_Sales', ascending=False).head(10).Name.reset_index(drop=True)
    best_selling_titles_by_genre_df[name] = temp_col

# %%
best_selling_titles_by_genre_df
# Out:
#                               Action                           Adventure  \
# 0                 Grand Theft Auto V                    Assassin's Creed
# 1      Grand Theft Auto: San Andreas  Super Mario Land 2: 6 Golden Coins
# 2                Grand Theft Auto IV                          L.A. Noire
# 3        Grand Theft Auto: Vice City     Zelda II: The Adventure of Link
# 4                     FIFA Soccer 13          Rugrats: Search For Reptar
# 5  LEGO Star Wars: The Complete Saga   Club Penguin: Elite Penguin Force
# 6         LEGO Batman: The Videogame                                Myst
# 7               Grand Theft Auto III                          Heavy Rain
# 8               Assassin's Creed III               Minecraft: Story Mode
# 9    Assassin's Creed IV: Black Flag             Rise of the Tomb Raider
#
#                                Fighting  \
# 0               Super Smash Bros. Brawl
# 1   Super Smash Bros. for Wii U and 3DS
# ...

# %% [markdown]
# # Conclusion

# %% [markdown]
# Las ventas y la cantidad de lanzamientos están estrechamente relacionadas, sin nada llamativo o sospechoso.
#
# El género "Acción" parece mantenerse más sólido ante la disminución en las ventas.
#
# Los géneros parecen ser consistentes al comparar su cantidad de lanzamientos y sus ingresos. Sin embargo, cuando consideramos el ingreso promedio por juego, los rankings cambian significativamente.
#
# La puntuación de los críticos es más conservadora pero se correlaciona mejor con las ventas, a diferencia de la puntuación de usuarios que tiene una correlación casi nula con las ventas.
#
# Japón sobresale como una región única en el mundo de los juegos, a diferencia del resto del mundo que muestra mayor coherencia. Por ejemplo, así es como los diferentes géneros se clasifican en ventas en cada una de las cuatro regiones.
#
# Los japoneses también muestran un fuerte apego a Nintendo como editor y al género "Rol".
#
# La lista de los mejores editores incluye a las 20 compañías principales que consistentemente lograron estar en las listas de los 10 mejores en varias métricas (como juegos más vendidos, ventas totales, etc.).
#
# Esas 20 compañías representan un poco más de la mitad (51.85%) de todos los juegos producidos y más de tres cuartas partes (76%) de todas las ventas globales. Este patrón sigue una tendencia general que encontramos en todo el conjunto de datos: la disminución exponencial.

# %% [markdown]
# ***Matias Vespa - 40325120***
